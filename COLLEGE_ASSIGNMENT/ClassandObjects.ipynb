# %% [markdown]
# # Python OOP Questions
# ## Classes and Objects
#
# ## Q1
# Create a class **Student** with the following attributes initialized using `__init__`:
#
# - name
# - roll_no
# - marks
# Create a method **display()** to print student details.
#
# ---
#
# ## Q2
# Create a class **Rectangle** that takes **length** and **breadth** using `__init__` and has a method **area()** to calculate the area.
#
# ---
# ## Q3
# Create a class **BankAccount** with the following attributes:
# - account_holder
# - balance
# Initialize using `__init__`.
# Create methods:
# - `deposit(amount)`
# - `withdraw(amount)`
# - `display_balance()`
# ---
# ## Q4
# Create a class **Book** with:
# - title
# - author
# - price
# Initialize using `__init__` and display book details.
# ---
# ## Q5
# Create a class **Employee** with:
# - name
# - basic_salary
# Initialize using `__init__`.
# Add a method to calculate **total salary**:
# - HRA = 20% of basic
# - DA = 10% of basic

# %%
class Student:
    def __init__(self,name,roll_no,marks):
        self.name=name
        self.roll_no=roll_no
        self.marks=marks
        
    def display(self):
        print("Name:",self.name)
        print("Roll No:", self.roll_no)
        print("Marks:", self.marks)

s1=Student("Sayan", 101, 85)
s1.display()
# Out:
# Name: Sayan
# Roll No: 101
# Marks: 85

# %%
class Rectangle:
    def __init__(self,length,breadth):
        self.length=length
        self.breadth=breadth
    def area(self):
        return self.length*self.breadth

r1=Rectangle(10,5)
print("Area of Rectangle:", r1.area())
# Out:
# Area of Rectangle: 50

# %%
class BankAccount:
    def __init__(self,account_holder,balance):
        self.account_holder=account_holder
        self.balance=balance
        
    def deposit(self,amount):
        self.balance+=amount
        print("Deposited:", amount)

    def withdraw(self,amount):
        if amount <= self.balance:
            self.balance-=amount
            print("Withdrawn:",amount)
        else:
            print("Insufficient Balance")

    def display_balance(self):
        print("Account Holder:",self.account_holder)
        print("Balance:", self.balance)

acc1=BankAccount("Sayan",5000)
acc1.deposit(2000)
acc1.withdraw(1500)
acc1.display_balance()
# Out:
# Deposited: 2000
# Withdrawn: 1500
# Account Holder: Sayan
# Balance: 5500

# %%
class Book:
    def __init__(self,title,author,price):
        self.title=title
        self.author=author
        self.price=price

    def display(self):
        print("Title:",self.title)
        print("Author:",self.author)
        print("Price:",self.price)

b1=Book("Let Us Python", "Aditya Kanetkar", 300)
b1.display()
# Out:
# Title: Let Us Python
# Author: Aditya Kanetkar
# Price: 300

# %%
class Employee:
    def __init__(self,name,basic_salary):
        self.name=name
        self.basic_salary=basic_salary

    def total_salary(self):
        hra=0.20*self.basic_salary
        da=0.10*self.basic_salary
        total=self.basic_salary+hra+da
        print("Name:",self.name)
        print("Basic Salary:",self.basic_salary)
        print("Total Salary:",total)

e1=Employee("Sayan", 30000)
e1.total_salary()
# Out:
# Name: Sayan
# Basic Salary: 30000
# Total Salary: 39000.0
