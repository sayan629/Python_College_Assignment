# %% [markdown]
# ## Assignment 13
#     - Sayan Pal (2570188)

# %%
class Book:
    def __init__(self,book_title,author,price):
        self.book_title=book_title;
        self.author=author
        self.price=price

    def display_book(self):
        print("Title:",self.book_title)
        print("Author:",self.author)
        print("Price:",self.price)

    def discount_price(self,percent):
        discount=(self.price * percent)/100
        final_price = self.price - discount
        print("Original Price:",self.price)
        print("Discount:", percent, "%")
        print("Final Price:",final_price)

b = Book("Python Basics", "John Smith", 500)
b.display_book()
b.discount_price(10)
# Out:
# Title: Python Basics
# Author: John Smith
# Price: 500
# Original Price: 500
# Discount: 10 %
# Final Price: 450.0

# %%
class Result:
    def __init__(self,student_name,math_marks,physics_marks,computer_marks):
        self.student_name=student_name
        self.math_marks=math_marks
        self.physics_marks=physics_marks
        self.computer_marks=computer_marks

    def total_marks(self):
        return self.math_marks + self.physics_marks + self.computer_marks

    def percentage(self):
        return self.total_marks()/3
        
    def result(self):
        if(self.math_marks>=40 and
           self.physics_marks>=40 and
           self.computer_marks>=40):
            print("Result:PASS")
        else:
            print("Result:FAIL")

r=Result("Sayan",75,60,55)
print("Total:", r.total_marks())
print("Percentage:",r.percentage())
r.result()
# Out:
# Total: 190
# Percentage: 63.333333333333336
# Result:PASS

# %%
class ShoppingCart:
    def __init__(self):
        self.items =[]

    def add_item(self,item_name,price):
        self.items.append([item_name,price])
        print(item_name, "added to cart")

    def remove_item(self,item_name):
        for item in self.items:
            if item[0] == item_name:
                self.items.remove(item)
                print(item_name, "removed from cart")
                return 
        print("Item not found")

    def calculate_total(self):
        total=0
        for item in self.items:
            total += item[1]
        print("Total Price:",total)
        
cart = ShoppingCart()
cart.add_item("Shirt", 500)
cart.add_item("Shoes", 1200)
cart.add_item("Watch", 800)
cart.remove_item("Shirt")
cart.calculate_total()
# Out:
# Shirt added to cart
# Shoes added to cart
# Watch added to cart
# Shirt removed from cart
# Total Price: 2000

# %%
class Temperature:
    def __init__(self,celsius):
        self.celsius=celsius

    def to_fahrenheit(self):
        return (self.celsius * 9/5) +32

    def to_kelvin(self):
        return self.celsius + 273.15

t=Temperature(25)
print("Fahrenheit:", t.to_fahrenheit())
print("Kelvin:", t.to_kelvin())
# Out:
# Fahrenheit: 77.0
# Kelvin: 298.15
